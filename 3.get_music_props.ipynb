# %%
import pandas as pd
import time
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
df = pd.read_csv('data_with_ids.csv').iloc[:,1:]
df2 = df.dropna()
df2 = df2.reset_index(drop=True)
df2
# Out:
#                             0  \
# 0                Karen Dalton
# 1                Jimmy Fallon
# 2      The New Basement Tapes
# 3                  Wolf Alice
# 4               The Waterboys
# 5           Left Lane Cruiser
# 6                        Band
# 7            Sharon Van Etten
# 8         The American Spirit
# 9                        Band
# 10                Blues Pills
# 11                  Bob Dylan
# 12               Led Zeppelin
# 13          The Wood Brothers
# 14               Sivert Høyem
# 15    Hearts Of Black Science
# 16                       IAMX
# 17          The Wood Brothers
# 18              Patrick James
# 19          The Wood Brothers
# 20                  K-essence
# 21                     Zacier
# 22             domowe melodie
# 23                 Corruption
# 24                  Two Timer
# 25             domowe melodie
# 26                  Two Timer
# 27                 Starsabout
# 28             Peter J. Birch
# 29                  Two Timer
# ...                       ...
# 7166                Tori Amos
# 7167               Nikki Hill
# 7168             Mark Lanegan
# 7169           Scarlet Chives
# 7170           Thomas Dybdahl
# 7171                Pearl Jam
# 7172              Vienna Teng
# 7173             Mark Lanegan
# 7174               Nik Turner
# 7175                 Dent May
# 7176                 Dent May
# 7177               Tim & Adam
# 7178                     Nico
# 7179               Tim & Adam
# 7180            Drew Danburry
# 7181                    Carta
# 7182      God Is an Astronaut
# 7183          Newton Faulkner
# 7184      God Is an Astronaut
# 7185           Okkervil River
# 7186                     Nico
# 7187                    Moddi
# 7188               Sorry Boys
# 7189      God Is an Astronaut
# 7190               Tim & Adam
# 7191                Deer Tick
# 7192                 Scanners
# 7193            Grey Reverend
# 7194            Drew Danburry
# 7195          Newton Faulkner
#
#                                                       1  \
# 0                                    Little Bit Of Rain
# 1                 Scrambled Eggs (Feat. Paul McCartney)
# 2                                         Nothing to It
# 3                                         You're A Germ
# 4                             I'll Be Your Baby Tonight
# 5                                   Whitebread n' Beans
# 6                                    Key To The Highway
# 7                                 Remembering Mountains
# 8                                        The News Today
# 9                      Time To Kill (Alternate Version)
# 10                                  No Hope Left For Me
# 11                                    Katie's been gone
# 12                                            Black Dog
# 13                                         River Of Sin
# 14                                     Sleepwalking Man
# 15                                                Faces
# 16                                     No Maker Made Me
# 17                                           Snake Eyes
# 18                                      Covered In Rain
# 19                                   American Heartache
# 20                                      Prince of Pawns
# 21                                        Odpad Atomowy
# 22                                             okruszek
# 23                   Story of Things That Should Not Be
# 24                                        Here It Comes
# 25                                              zbyszek
# 26                                                 Moon
# 27                                      Black Rain Love
# 28                                    Inexcusable blues
# 29                                                  Ego
# ...                                                 ...
# 7166                                    Not David Bowie
# 7167                                       And I Wonder
# 7168                                     Mack The Knife
# 7169                                            Hunting
# 7170                          This Love Is Here To Stay
# 7171                                             Sirens
# 7172                             Copenhagen (Let Me Go)
# 7173                                      Autumn Leaves
# 7174                              Fallen Angel Sts-51-L
# 7175                                     Summer Is Over
# 7176                               Turn Up The Speakers
# 7177                               Forest for the Trees
# 7178                                       Femme Fatale
# 7179                                   One Little Taste
# 7180                           Nobody Listens to Turtle
# 7181                                The Iowa FIght Song
# 7182                              Light Years From Home
# 7183                                         Indecisive
# 7184                                     The Last March
# 7185                           Down Down the Deep River
# 7186                                            The End
# 7187                                       Floriography
# 7188                                            Phoenix
# 7189                                        Autumn Song
# 7190                                  Stranger Stranger
# 7191                           The Dream's In The Ditch
# 7192                                   Love Is Symmetry
# 7193                                        Nightingale
# 7194  Jerry Spinelli and Patricia Polacco or Every M...
# 7195                                     Where to Start
#
#                           id
# 0     09g4TuWLxMmrOTt1kzS47Z
# 1     4tjMa8XQd7CsVlCXmNSP8f
# 2     0NBQB7SAdzOHmNEZSPrR8U
# 3     7uEDFuKsEsRSbVTVwHTt78
# 4     2FmJ2jfPaBWWouaEAw7Juz
# 5     0YC1UfDTE5DVFNivVsKvWQ
# 6     7zX9fAnniTOdTsSV8eipxM
# 7     2zW0oWOUOc8KDLBCJXT80T
# 8     6cW25d5mAZpx8kqhs8mqUG
# 9     26JWZEYpKwW2EEJyBr2EYe
# 10    081jSku6j1gIKEsIZnDbzv
# 11    2OiysLw55VVjAYj1tC2TMF
# 12    3qT4bUD1MaWpGrTwcvguhb
# 13    33iZLYRB4Ehx3KW6QMwHX1
# 14    0A09FlKwoGpCzSo14RT3DH
# 15    6dZYkF2S9bKjwGN5KWpsrP
# 16    291bFWMvwZg6k8t4l1CElk
# 17    7u7UJtOy2IfGd40VLXnYu6
# 18    4itTLOx6UcETVQ7MPPKsvF
# 19    0vZX2wBIDrHnrluusVDL4n
# 20    61lb5LBwjhfA7zQhf7jKnG
# 21    6PQS84dBs9ic1pLcUCLMwd
# 22    6DxDKl5nrkbzgXLoBhtFuU
# 23    4IqiOvJxfcZ45a7gb6iIhg
# 24    1gEMzWEP9wgVRukRA7eWnc
# 25    72ULSTKPQiUiandYGdVvy1
# 26    56VtaL1EU4PxJ5n6nR4RVk
# 27    4FZWiE7unEgbN8wAv1lXlF
# 28    0tJgkHRn6b7rcFf8GoMD7C
# 29    1oAKcVPTmYOGsyymYUOuhR
# ...                      ...
# 7166  3Taea1kIYruhSuulWDsNk9
# 7167  4uGaAUzv10JWDPcq0vty1M
# 7168  2cJPOAsEqYjABKEJmkpsAc
# 7169  3BU3CCe6WQ40McWgjSIkzb
# 7170  4rcqXgxRAvUCldIRNK6vu1
# 7171  1cAMXz9mnvrqyQLSG4KeeE
# 7172  1ZWIYSEQDqxZ2Er7wa97MK
# 7173  32yuEmnBuKqGrIjUmBF8lM
# 7174  1lUoAPK88efTdibifRKoAi
# 7175  6i56iyJ4yH8tQHBuKz4id2
# 7176  4bUPHVQGSvZwifH7EuCxH6
# 7177  0Xx0FatTpwvTGG5hWlG3j1
# 7178  64AH1uL0vz8PitgBCnwyRH
# 7179  4mhlyu2uLq4dmLv3dXXkaq
# 7180  7tHPxZDpwL5xHbIUqieBCE
# 7181  18oGX7GF69lPQgJjrszsW7
# 7182  4NQqX25RHZOVfIua82Zlef
# 7183  1EFNpwVrsU7KXqvR7YNj0L
# 7184  0CpibaJlmN4ZU5MhovLQf7
# 7185  1SIQLf6ZWauO1fcPxl9lvB
# 7186  2vGZB2t9GTDiXzoc3cSPf0
# 7187  4c7EvOX9f6ZgwVH4cioakC
# 7188  6eOKE50B17zKRMFt4Dmiph
# 7189  4m55btBd5hMnrfAyfjCGcU
# 7190  1kMymRZiCMM9LCZhaQLjYo
# 7191  2A9Zm100yFB3CHQd6kFaB7
# 7192  7iNhd7VMzCksx95F5U2fwm
# 7193  61gWdT8wUYeT7Ef3S5MMQf
# 7194  4kYkOVzz0bnopnpknDYah3
# 7195  0buBIfKbc3SiOhvHF1dNQr
#
# [7196 rows x 3 columns]

# %%
# %run -i '1. ids.py'


client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)


for x in range(len(df2.index)):
    ids= df2.iloc[x,2]
    track_id = sp.audio_features(ids)
    for item in track_id:
        df2.loc[x, 'id2' ]= item['id']
        df2.loc[x, 'danceability'] = item['danceability']
        df2.loc[x, 'energy'] = item['energy']
        df2.loc[x, 'key'] = item['key']
        df2.loc[x, 'loudness'] = item['loudness']
        df2.loc[x, 'mode'] = item['mode']
        df2.loc[x, 'speechiness'] = item['speechiness']
        df2.loc[x, 'acousticness'] = item['acousticness']
        df2.loc[x, 'instrumentalness'] = item['instrumentalness']
        df2.loc[x, 'liveness'] = item['liveness']
        df2.loc[x, 'valence'] = item['valence']
        df2.loc[x, 'tempo'] = item['tempo']
        df2.loc[x, 'type'] = item['type']
        df2.loc[x, 'type'] = item['type']
        df2.loc[x, 'duration_ms'] = item['duration_ms']
        df2.loc[x, 'time_signature'] = item['time_signature']
        
    if not x % 50:
        print(x)
        time.sleep(2)
# Out:
# 0
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 2550
# 2600
# 2650
# 2700
# 2750
# 2800
# 2850
# 2900
# 2950
# 3000
# 3050
# 3100
# 3150
# 3200
# 3250
# 3300
# 3350
# 3400
# 3450
# 3500
# 3550
# 3600
# 3650
# 3700
# 3750
# 3800
# 3850
# 3900
# 3950
# 4000
# 4050
# 4100
# 4150
# 4200
# 4250
# 4300
# 4350
# 4400
# 4450
# 4500
# 4550
# 4600
# 4650
# 4700
# 4750
# 4800
# 4850
# 4900
# 4950
# 5000
# 5050
# 5100
# 5150
# 5200
# 5250
# 5300
# 5350
# 5400
# 5450
# 5500
# 5550
# 5600
# 5650
# 5700
# 5750
# 5800
# 5850
# 5900
# 5950
# 6000
# 6050
# 6100
# 6150
# 6200
# 6250
# 6300
# 6350
# 6400
# 6450
# 6500
# 6550
# 6600
# 6650
# 6700
# 6750
# 6800
# 6850
# 6900
# 6950
# 7000
# 7050
# 7100
# 7150

# %%
df3 = df2.dropna()

# %%
df2.to_csv('data_with_props.csv')

# %%
track_id
# Out:
# [{'danceability': 0.464,
#   'energy': 0.494,
#   'key': 6,
#   'loudness': -9.147,
#   'mode': 1,
#   'speechiness': 0.0345,
#   'acousticness': 0.662,
#   'instrumentalness': 7.24e-05,
#   'liveness': 0.136,
#   'valence': 0.251,
#   'tempo': 104.04,
#   'type': 'audio_features',
#   'id': '0buBIfKbc3SiOhvHF1dNQr',
#   'uri': 'spotify:track:0buBIfKbc3SiOhvHF1dNQr',
#   'track_href': 'https://api.spotify.com/v1/tracks/0buBIfKbc3SiOhvHF1dNQr',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0buBIfKbc3SiOhvHF1dNQr',
#   'duration_ms': 189240,
#   'time_signature': 4}]

# %%
df2.isna().sum()
# Out:
# 0                   0
# 1                   0
# id                  0
# id2                 0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# type                0
# duration_ms         0
# time_signature      0
# dtype: int64

# %%
df2.head()
# Out:
#                         0                                      1  \
# 0            Karen Dalton                     Little Bit Of Rain
# 1            Jimmy Fallon  Scrambled Eggs (Feat. Paul McCartney)
# 2  The New Basement Tapes                          Nothing to It
# 3              Wolf Alice                          You're A Germ
# 4           The Waterboys              I'll Be Your Baby Tonight
#
#                        id                     id2  danceability  energy   key  \
# 0  09g4TuWLxMmrOTt1kzS47Z  09g4TuWLxMmrOTt1kzS47Z         0.432  0.0554   2.0
# 1  4tjMa8XQd7CsVlCXmNSP8f  4tjMa8XQd7CsVlCXmNSP8f         0.392  0.4040  11.0
# 2  0NBQB7SAdzOHmNEZSPrR8U  0NBQB7SAdzOHmNEZSPrR8U         0.549  0.7370   6.0
# 3  7uEDFuKsEsRSbVTVwHTt78  7uEDFuKsEsRSbVTVwHTt78         0.628  0.8350   7.0
# 4  2FmJ2jfPaBWWouaEAw7Juz  2FmJ2jfPaBWWouaEAw7Juz         0.278  0.7380   2.0
#
#    loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0   -22.279   1.0       0.0395      0.925000           0.07490     0.101
# 1    -8.338   1.0       0.0354      0.851000           0.00000     0.871
# 2    -8.233   1.0       0.0414      0.082000           0.01270     0.162
# 3    -6.519   1.0       0.0620      0.000881           0.17400     0.322
# 4    -6.052   1.0       0.0512      0.227000           0.00004     0.170
#
#    valence    tempo            type  duration_ms  time_signature
# 0    0.361  173.945  audio_features     156893.0             3.0
# 1    0.363   81.822  audio_features     155307.0             4.0
# 2    0.606  120.650  audio_features     212000.0             4.0
# 3    0.577  138.035  audio_features     173160.0             4.0
# 4    0.547  113.753  audio_features     216587.0             4.0

# %%
df2.tail()
# Out:
#                     0                                                  1  \
# 7191        Deer Tick                           The Dream's In The Ditch
# 7192         Scanners                                   Love Is Symmetry
# 7193    Grey Reverend                                        Nightingale
# 7194    Drew Danburry  Jerry Spinelli and Patricia Polacco or Every M...
# 7195  Newton Faulkner                                     Where to Start
#
#                           id                     id2  danceability  energy  \
# 7191  2A9Zm100yFB3CHQd6kFaB7  2A9Zm100yFB3CHQd6kFaB7         0.652   0.913
# 7192  7iNhd7VMzCksx95F5U2fwm  7iNhd7VMzCksx95F5U2fwm         0.419   0.934
# 7193  61gWdT8wUYeT7Ef3S5MMQf  61gWdT8wUYeT7Ef3S5MMQf         0.598   0.384
# 7194  4kYkOVzz0bnopnpknDYah3  4kYkOVzz0bnopnpknDYah3         0.518   0.127
# 7195  0buBIfKbc3SiOhvHF1dNQr  0buBIfKbc3SiOhvHF1dNQr         0.464   0.494
#
#       key  loudness  mode  speechiness  acousticness  instrumentalness  \
# 7191  5.0    -4.980   1.0       0.0399        0.1220          0.005930
# 7192  7.0    -0.664   1.0       0.1380        0.0118          0.000059
# 7193  2.0   -10.046   1.0       0.0546        0.3970          0.002240
# 7194  0.0   -11.483   1.0       0.0345        0.7020          0.000004
# 7195  6.0    -9.147   1.0       0.0345        0.6620          0.000072
#
#       liveness  valence    tempo            type  duration_ms  time_signature
# 7191    0.1150    0.905  124.832  audio_features     191581.0             4.0
# 7192    0.5470    0.312  129.954  audio_features     212308.0             4.0
# 7193    0.1420    0.563  209.566  audio_features     234960.0             4.0
# 7194    0.0973    0.129  119.861  audio_features     224173.0             4.0
# 7195    0.1360    0.251  104.040  audio_features     189240.0             4.0
