# %%
import pandas as pd
import time
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
df = pd.read_csv('albums_with_props.csv').iloc[:,1:]
df = df.dropna()
df.isna().sum()
# Out:
# artist              0
# album               0
# track_title         0
# track_title.1       0
# track_id            0
# id2                 0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# type                0
# duration_ms         0
# time_signature      0
# dtype: int64

# %%
df2 = df.copy()

# %%
# %run -i '1. ids.py'


client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)


for x in range(len(df2.index)):
    ids= df2.iloc[x,4]
    track_data = sp.audio_analysis(ids)
    if track_data != [None]:
        
        bars = 0
        for item in track_data['bars']:
             bars += 1
        df2.loc[x, 'bars'] = bars
        sections = 0
        for item in track_data['sections']:
            sections += 1
        df2.loc[x, 'sections'] = sections
        segments = 0
        for item in track_data['segments']:
            segments += 1
        df2.loc[x, 'segments'] = segments    

        if not x % 50:
            print(x)
            time.sleep(2)
# Out:
# 0
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 2550
# 2600
# 2650
# 2700
# 2750
# 2800
# 2850
# 2900
# 2950
# 3000
# 3050
# 3100
# 3150

# %%
df2 = df2.dropna()

print(df2.isna().sum())
# Out:
# artist              0
# album               0
# track_title         0
# track_title.1       0
# track_id            0
# id2                 0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# type                0
# duration_ms         0
# time_signature      0
# bars                0
# sections            0
# segments            0
# dtype: int64

# %%
df2.to_csv('albums_with_props.csv')

# %%
df2.head()
# Out:
#        artist        album              track_title  track_title.1  \
# 0  Two People  First Body          I'm Tied, To You              1
# 1  Two People  First Body             In The Garden              2
# 2  Two People  First Body        Look At Each Other              3
# 3  Two People  First Body   Something To Talk About              4
# 4  Two People  First Body                Phone Call              5
#
#                  track_id                     id2  danceability  energy   key  \
# 0  4EtV7bwr5Y2tSScH6WVznD  4EtV7bwr5Y2tSScH6WVznD         0.296   0.599   3.0
# 1  0tJkh1UHlb8SSAJQXMVpA8  0tJkh1UHlb8SSAJQXMVpA8         0.584   0.634  11.0
# 2  00QQPk2L7pJ1lutMyMg9y7  00QQPk2L7pJ1lutMyMg9y7         0.520   0.571  11.0
# 3  3j5DPSY4mg6gDKvsE4tjp3  3j5DPSY4mg6gDKvsE4tjp3         0.622   0.490   5.0
# 4  3O7UyyZUP6kGR3yfpL2GdY  3O7UyyZUP6kGR3yfpL2GdY         0.414   0.391   2.0
#
#    loudness    ...     instrumentalness  liveness  valence    tempo  \
# ...

# %%
df2.tail()
# Out:
#                   artist    album  \
# 3185  Michel Petrucciani  Colors
# 3186  Michel Petrucciani  Colors
# 3187  Michel Petrucciani  Colors
# 3188  Michel Petrucciani  Colors
# 3189  Michel Petrucciani  Colors
#
#                                             track_title  track_title.1  \
# 3185                                      Petite Louise             14
# 3186   She Did It Again - Live; 2007 Remastered Version             15
# 3187                                    Even Mice Dance             16
# 3188  Romantic but not Blue - Live; 2007 Remastered ...             17
# 3189                                         Montelimar             18
#
#                     track_id                     id2  danceability  energy  \
# 3185  7p2OYSvpkuPnyY7b08kw0C  7p2OYSvpkuPnyY7b08kw0C         0.398   0.255
# 3186  42IbQehOoMCJ6FhAQUvOj1  42IbQehOoMCJ6FhAQUvOj1         0.407   0.384
# 3187  5gTw7HcahcrAj0AqjFDrTe  5gTw7HcahcrAj0AqjFDrTe         0.368   0.527
# ...
