# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, ParameterGrid
import collections


from sklearn import svm
from sklearn.neighbors import LocalOutlierFactor
from sklearn.ensemble import IsolationForest

# %%
X = pd.read_csv('data_with_props.csv').iloc[:,5:]
X = X.drop('type', axis=1)
X_out = pd.read_csv('albums_with_props.csv').iloc[:,7:]
X_out = X_out.drop('type', axis=1)

# %%
X_train, X_test = train_test_split(X, test_size=0.1, random_state=42)

# %%
def custom_scoring(clf, X_out, X_train):
    
    y_pred_train = clf.predict(X_train)
    y_pred_out = clf.predict(X_out)
    

    a = collections.Counter(y_pred_train)
    b = collections.Counter(y_pred_out)
    print(a)
    print(b)
    try:
        train = dict(a.items())[1]/(dict(a.items())[-1] + dict(a.items())[1])
        outside = dict(b.items())[-1]/(dict(b.items())[1] + dict(b.items())[-1])
        print(train)
        print(outside)
    except:
        train = 0
        
    if train > 0.8 and outside <0.8:
        result = outside
        print(result)
    else:
        result = 0

        
    return(result)

# %%
def fit_and_display(grid, clf, X_out, X_train):
    best_score_list = [0]
    best_params_list = []
    for g in ParameterGrid(grid):
        clf.set_params(**g)
        clf.fit(X_train)
        score = custom_scoring(clf, X_out, X_train)
        if score > max(best_score_list):
            
            best_score_list.append(score)
            params = clf.get_params(deep=True)
            best_params_list.append(clf.get_params(params))
            print("")
            print('***********************')
            print('Best at the moment!')
            print(score)
            print(clf.get_params(deep=True))
            print('***********************')
            print("")
    return(best_score_list, best_params_list)

# %%
def check_best_result(clf, best_params_list, X_train, X_test, X_out):
    clf.set_params(**best_params_list[-1])

    y_pred_train = clf.predict(X_train)
    y_pred_test = clf.predict(X_test)
    y_pred_out = clf.predict(X_out)
    print('Values for train, test and out:')
    a = (collections.Counter(y_pred_train))
    b = (collections.Counter(y_pred_test))
    c = (collections.Counter(y_pred_out))
    print('Scoring for train, test and out')
    train = dict(a.items())[1]/(dict(a.items())[-1] + dict(a.items())[1])
    test = dict(b.items())[1]/(dict(b.items())[-1] + dict(b.items())[1])
    outside = dict(c.items())[-1]/(dict(c.items())[1] + dict(c.items())[-1])
    print(train, test, outside)
    print('Parameters of the best estimator:')
    print(clf.get_params)

# %%
kernels = [ 'poly', 'rbf', 'sigmoid', 'linear']
degree = [2,3,4,5,6]
gammas = [0.001, 0.01, 0.1, 1]
nus = [0.01, 0.1, 0.15, 0.2, 0.3, 0.4, 0.5]
tols = [0.001, 0.01, 0.1]
grid = {'degree': degree, 'gamma' : gammas, 'kernel' : kernels, 'nu' : nus, 'tol' : tols}
clf = svm.OneClassSVM(verbose=10)

best_score_list, best_params_list = fit_and_display(grid, clf, X_out, X_train)
# Out:
# [LibSVM]Counter({1: 6411, -1: 65})
# Counter({1: 3071, -1: 119})
# 0.9899629400864731
# 0.037304075235109715
# 0.037304075235109715
#
# ***********************
# Best at the moment!
# 0.037304075235109715
# {'cache_size': 200, 'coef0': 0.0, 'degree': 2, 'gamma': 0.001, 'kernel': 'poly', 'max_iter': -1, 'nu': 0.01, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': 10}
# ***********************
#
# [LibSVM]Counter({1: 6411, -1: 65})
# Counter({1: 3071, -1: 119})
# 0.9899629400864731
# 0.037304075235109715
# 0.037304075235109715
# [LibSVM]Counter({1: 6411, -1: 65})
# Counter({1: 3071, -1: 119})
# 0.9899629400864731
# 0.037304075235109715
# 0.037304075235109715
# [LibSVM]Counter({1: 5828, -1: 648})
# Counter({1: 2575, -1: 615})
# 0.8999382334774553
# 0.19278996865203762
# 0.19278996865203762
#
# ***********************
# Best at the moment!
# 0.19278996865203762
# {'cache_size': 200, 'coef0': 0.0, 'degree': 2, 'gamma': 0.001, 'kernel': 'poly', 'max_iter': -1, 'nu': 0.1, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': 10}
# ***********************
#
# [LibSVM]Counter({1: 5828, -1: 648})
# Counter({1: 2575, -1: 615})
# 0.8999382334774553
# 0.19278996865203762
# 0.19278996865203762
# [LibSVM]Counter({1: 5828, -1: 648})
# Counter({1: 2575, -1: 615})
# 0.8999382334774553
# 0.19278996865203762
# 0.19278996865203762
# [LibSVM]Counter({1: 5504, -1: 972})
# Counter({1: 2388, -1: 802})
# 0.8499073502161828
# 0.25141065830721004
# 0.25141065830721004
#
# ***********************
# Best at the moment!
# 0.25141065830721004
# {'cache_size': 200, 'coef0': 0.0, 'degree': 2, 'gamma': 0.001, 'kernel': 'poly', 'max_iter': -1, 'nu': 0.15, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': 10}
# ***********************
#
# [LibSVM]Counter({1: 5504, -1: 972})
# Counter({1: 2388, -1: 802})
# 0.8499073502161828
# 0.25141065830721004
# 0.25141065830721004
# [LibSVM]Counter({1: 5504, -1: 972})
# Counter({1: 2388, -1: 802})
# 0.8499073502161828
# 0.25141065830721004
# 0.25141065830721004
# [LibSVM]Counter({1: 5181, -1: 1295})
# Counter({1: 2193, -1: 997})
# 0.8000308832612724
# 0.31253918495297806
# 0.31253918495297806
#
# ***********************
# Best at the moment!
# 0.31253918495297806
# {'cache_size': 200, 'coef0': 0.0, 'degree': 2, 'gamma': 0.001, 'kernel': 'poly', 'max_iter': -1, 'nu': 0.2, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': 10}
# ***********************
#
# [LibSVM]Counter({1: 5181, -1: 1295})
# Counter({1: 2193, -1: 997})
# 0.8000308832612724
# 0.31253918495297806
# 0.31253918495297806
# [LibSVM]Counter({1: 5181, -1: 1295})
# Counter({1: 2193, -1: 997})
# 0.8000308832612724
# 0.31253918495297806
# 0.31253918495297806
# [LibSVM]Counter({1: 4534, -1: 1942})
# Counter({1: 1816, -1: 1374})
# 0.7001235330450896
# 0.4307210031347962
# [LibSVM]Counter({1: 4534, -1: 1942})
# Counter({1: 1816, -1: 1374})
# 0.7001235330450896
# 0.4307210031347962
# [LibSVM]Counter({1: 4534, -1: 1942})
# Counter({1: 1816, -1: 1374})
# 0.7001235330450896
# 0.4307210031347962
# [LibSVM]Counter({1: 3885, -1: 2591})
# Counter({-1: 1695, 1: 1495})
# 0.5999073502161828
# 0.5313479623824452
# [LibSVM]Counter({1: 3885, -1: 2591})
# Counter({-1: 1695, 1: 1495})
# 0.5999073502161828
# 0.5313479623824452
# [LibSVM]Counter({1: 3885, -1: 2591})
# Counter({-1: 1695, 1: 1495})
# 0.5999073502161828
# 0.5313479623824452
# [LibSVM]Counter({-1: 3238, 1: 3238})
# Counter({-1: 1973, 1: 1217})
# 0.5
# 0.6184952978056426
# [LibSVM]Counter({-1: 3238, 1: 3238})
# Counter({-1: 1973, 1: 1217})
# 0.5
# 0.6184952978056426
# [LibSVM]Counter({-1: 3238, 1: 3238})
# Counter({-1: 1973, 1: 1217})
# 0.5
# 0.6184952978056426
# [LibSVM]Counter({1: 3775, -1: 2701})
# Counter({-1: 3188, 1: 2})
# 0.5829215565163681
# 0.9993730407523511
# [LibSVM]Counter({-1: 3627, 1: 2849})
# Counter({-1: 3185, 1: 5})
# 0.43993205682520076
# 0.9984326018808778
# [LibSVM]Counter({-1: 6467, 1: 9})
# Counter({-1: 3190})
# [LibSVM]Counter({1: 3653, -1: 2823})
# Counter({-1: 3190})
# [LibSVM]Counter({1: 3355, -1: 3121})
# Counter({-1: 3188, 1: 2})
# 0.5180667078443484
# 0.9993730407523511
# [LibSVM]Counter({1: 5240, -1: 1236})
# Counter({-1: 3188, 1: 2})
# 0.8091414453366276
# 0.9993730407523511
# [LibSVM]Counter({-1: 3666, 1: 2810})
# Counter({-1: 3190})
# [LibSVM]Counter({1: 4827, -1: 1649})
# Counter({-1: 3188, 1: 2})
# 0.7453675108091414
# 0.9993730407523511
# [LibSVM]Counter({1: 4466, -1: 2010})
# Counter({-1: 3189, 1: 1})
# 0.6896232242124768
# 0.9996865203761756
# [LibSVM]Counter({-1: 3393, 1: 3083})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 4347, 1: 2129})
# Counter({-1: 3189, 1: 1})
# 0.32875231624459544
# 0.9996865203761756
# [LibSVM]Counter({1: 4245, -1: 2231})
# Counter({-1: 3188, 1: 2})
# 0.6554972205064855
# 0.9993730407523511
# [LibSVM]Counter({1: 3985, -1: 2491})
# Counter({-1: 3190})
# [LibSVM]Counter({1: 4227, -1: 2249})
# Counter({-1: 3190})
# [LibSVM]Counter({1: 3282, -1: 3194})
# Counter({-1: 3188, 1: 2})
# 0.5067943174799259
# 0.9993730407523511
# [LibSVM]Counter({-1: 3381, 1: 3095})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 3415, 1: 3061})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 4148, 1: 2328})
# Counter({-1: 3189, 1: 1})
# 0.35948116121062385
# 0.9996865203761756
# [LibSVM]Counter({-1: 3307, 1: 3169})
# Counter({-1: 3190})
# [LibSVM]Counter({1: 3261, -1: 3215})
# Counter({-1: 3189, 1: 1})
# 0.5035515750463249
# 0.9996865203761756
# [LibSVM]Counter({-1: 4820, 1: 1656})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({1: 6412, -1: 64})
# Counter({1: 3071, -1: 119})
# 0.990117356392835
# 0.037304075235109715
# 0.037304075235109715
# [LibSVM]Counter({1: 6412, -1: 64})
# Counter({1: 3071, -1: 119})
# 0.990117356392835
# 0.037304075235109715
# 0.037304075235109715
# [LibSVM]Counter({1: 6412, -1: 64})
# Counter({1: 3071, -1: 119})
# 0.990117356392835
# 0.037304075235109715
# 0.037304075235109715
# [LibSVM]Counter({1: 5828, -1: 648})
# Counter({1: 2575, -1: 615})
# 0.8999382334774553
# 0.19278996865203762
# 0.19278996865203762
# [LibSVM]Counter({1: 5828, -1: 648})
# Counter({1: 2575, -1: 615})
# 0.8999382334774553
# 0.19278996865203762
# 0.19278996865203762
# [LibSVM]Counter({1: 5828, -1: 648})
# Counter({1: 2575, -1: 615})
# 0.8999382334774553
# 0.19278996865203762
# 0.19278996865203762
# [LibSVM]Counter({1: 5505, -1: 971})
# Counter({1: 2388, -1: 802})
# 0.8500617665225447
# 0.25141065830721004
# 0.25141065830721004
# [LibSVM]Counter({1: 5505, -1: 971})
# Counter({1: 2388, -1: 802})
# 0.8500617665225447
# 0.25141065830721004
# 0.25141065830721004
# [LibSVM]Counter({1: 5505, -1: 971})
# Counter({1: 2388, -1: 802})
# 0.8500617665225447
# 0.25141065830721004
# 0.25141065830721004
# [LibSVM]Counter({1: 5181, -1: 1295})
# Counter({1: 2193, -1: 997})
# 0.8000308832612724
# 0.31253918495297806
# 0.31253918495297806
# [LibSVM]Counter({1: 5181, -1: 1295})
# Counter({1: 2193, -1: 997})
# 0.8000308832612724
# 0.31253918495297806
# 0.31253918495297806
# [LibSVM]Counter({1: 5181, -1: 1295})
# Counter({1: 2193, -1: 997})
# 0.8000308832612724
# 0.31253918495297806
# 0.31253918495297806
# [LibSVM]Counter({1: 4533, -1: 1943})
# Counter({1: 1816, -1: 1374})
# 0.6999691167387276
# 0.4307210031347962
# [LibSVM]Counter({1: 4533, -1: 1943})
# Counter({1: 1816, -1: 1374})
# 0.6999691167387276
# 0.4307210031347962
# [LibSVM]Counter({1: 4533, -1: 1943})
# Counter({1: 1816, -1: 1374})
# 0.6999691167387276
# 0.4307210031347962
# [LibSVM]Counter({1: 3886, -1: 2590})
# Counter({-1: 1695, 1: 1495})
# 0.6000617665225447
# 0.5313479623824452
# [LibSVM]Counter({1: 3886, -1: 2590})
# Counter({-1: 1695, 1: 1495})
# 0.6000617665225447
# 0.5313479623824452
# [LibSVM]Counter({1: 3886, -1: 2590})
# Counter({-1: 1695, 1: 1495})
# 0.6000617665225447
# 0.5313479623824452
# [LibSVM]Counter({-1: 3238, 1: 3238})
# Counter({-1: 1973, 1: 1217})
# 0.5
# 0.6184952978056426
# [LibSVM]Counter({-1: 3238, 1: 3238})
# Counter({-1: 1973, 1: 1217})
# 0.5
# 0.6184952978056426
# [LibSVM]Counter({-1: 3238, 1: 3238})
# Counter({-1: 1973, 1: 1217})
# 0.5
# 0.6184952978056426
# [LibSVM]Counter({1: 6412, -1: 64})
# Counter({1: 3071, -1: 119})
# 0.990117356392835
# 0.037304075235109715
# 0.037304075235109715
# [LibSVM]Counter({1: 6412, -1: 64})
# Counter({1: 3071, -1: 119})
# 0.990117356392835
# 0.037304075235109715
# 0.037304075235109715
# [LibSVM]Counter({1: 6412, -1: 64})
# Counter({1: 3071, -1: 119})
# 0.990117356392835
# 0.037304075235109715
# 0.037304075235109715
# [LibSVM]Counter({1: 5828, -1: 648})
# Counter({1: 2575, -1: 615})
# 0.8999382334774553
# 0.19278996865203762
# 0.19278996865203762
# [LibSVM]Counter({1: 5828, -1: 648})
# Counter({1: 2575, -1: 615})
# 0.8999382334774553
# 0.19278996865203762
# 0.19278996865203762
# [LibSVM]Counter({1: 5828, -1: 648})
# Counter({1: 2575, -1: 615})
# 0.8999382334774553
# 0.19278996865203762
# 0.19278996865203762
# [LibSVM]Counter({1: 5505, -1: 971})
# Counter({1: 2388, -1: 802})
# 0.8500617665225447
# 0.25141065830721004
# 0.25141065830721004
# [LibSVM]Counter({1: 5505, -1: 971})
# Counter({1: 2388, -1: 802})
# 0.8500617665225447
# 0.25141065830721004
# 0.25141065830721004
# [LibSVM]Counter({1: 5505, -1: 971})
# Counter({1: 2388, -1: 802})
# 0.8500617665225447
# 0.25141065830721004
# 0.25141065830721004
# [LibSVM]Counter({1: 5180, -1: 1296})
# Counter({1: 2193, -1: 997})
# 0.7998764669549104
# 0.31253918495297806
# [LibSVM]Counter({1: 5180, -1: 1296})
# Counter({1: 2193, -1: 997})
# 0.7998764669549104
# 0.31253918495297806
# [LibSVM]Counter({1: 5180, -1: 1296})
# Counter({1: 2193, -1: 997})
# 0.7998764669549104
# 0.31253918495297806
# [LibSVM]Counter({1: 4533, -1: 1943})
# Counter({1: 1816, -1: 1374})
# 0.6999691167387276
# 0.4307210031347962
# [LibSVM]Counter({1: 4533, -1: 1943})
# Counter({1: 1816, -1: 1374})
# 0.6999691167387276
# 0.4307210031347962
# [LibSVM]Counter({1: 4533, -1: 1943})
# Counter({1: 1816, -1: 1374})
# 0.6999691167387276
# 0.4307210031347962
# [LibSVM]Counter({1: 3885, -1: 2591})
# Counter({-1: 1695, 1: 1495})
# 0.5999073502161828
# 0.5313479623824452
# [LibSVM]Counter({1: 3885, -1: 2591})
# Counter({-1: 1695, 1: 1495})
# 0.5999073502161828
# 0.5313479623824452
# [LibSVM]Counter({1: 3885, -1: 2591})
# Counter({-1: 1695, 1: 1495})
# 0.5999073502161828
# 0.5313479623824452
# [LibSVM]Counter({-1: 3238, 1: 3238})
# Counter({-1: 1973, 1: 1217})
# 0.5
# 0.6184952978056426
# [LibSVM]Counter({-1: 3238, 1: 3238})
# Counter({-1: 1973, 1: 1217})
# 0.5
# 0.6184952978056426
# [LibSVM]Counter({-1: 3238, 1: 3238})
# Counter({-1: 1973, 1: 1217})
# 0.5
# 0.6184952978056426
# [LibSVM]Counter({-1: 4033, 1: 2443})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 3760, 1: 2716})
# Counter({-1: 3189, 1: 1})
# 0.41939468807906116
# 0.9996865203761756
# [LibSVM]Counter({-1: 6467, 1: 9})
# Counter({-1: 3190})
# [LibSVM]Counter({1: 6109, -1: 367})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 4759, 1: 1717})
# Counter({-1: 3190})
# [LibSVM]Counter({1: 5057, -1: 1419})
# Counter({-1: 3188, 1: 2})
# 0.7808832612723904
# 0.9993730407523511
# [LibSVM]Counter({1: 6002, -1: 474})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 4190, 1: 2286})
# Counter({-1: 3189, 1: 1})
# 0.3529956763434219
# 0.9996865203761756
# [LibSVM]Counter({1: 4385, -1: 2091})
# Counter({-1: 3188, 1: 2})
# 0.6771155033971588
# 0.9993730407523511
# [LibSVM]Counter({1: 6041, -1: 435})
# Counter({-1: 3190})
# [LibSVM]Counter({1: 3265, -1: 3211})
# Counter({-1: 3190})
# [LibSVM]Counter({1: 3609, -1: 2867})
# Counter({-1: 3189, 1: 1})
# 0.5572884496602841
# 0.9996865203761756
# [LibSVM]Counter({1: 5774, -1: 702})
# Counter({-1: 3190})
# [LibSVM]Counter({1: 4724, -1: 1752})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 4160, 1: 2316})
# Counter({-1: 3190})
# [LibSVM]Counter({1: 5833, -1: 643})
# Counter({-1: 3190})
# [LibSVM]Counter({1: 6267, -1: 209})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 5546, 1: 930})
# Counter({-1: 3190})
# [LibSVM]Counter({1: 5583, -1: 893})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 4913, 1: 1563})
# Counter({-1: 3189, 1: 1})
# 0.2413526868437307
# 0.9996865203761756
# [LibSVM]Counter({1: 5833, -1: 643})
# Counter({-1: 3189, 1: 1})
# 0.900710315009265
# 0.9996865203761756
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({1: 6412, -1: 64})
# Counter({1: 3071, -1: 119})
# 0.990117356392835
# 0.037304075235109715
# 0.037304075235109715
# [LibSVM]Counter({1: 6412, -1: 64})
# Counter({1: 3071, -1: 119})
# 0.990117356392835
# 0.037304075235109715
# 0.037304075235109715
# [LibSVM]Counter({1: 6412, -1: 64})
# Counter({1: 3071, -1: 119})
# 0.990117356392835
# 0.037304075235109715
# 0.037304075235109715
# [LibSVM]Counter({1: 5828, -1: 648})
# Counter({1: 2575, -1: 615})
# 0.8999382334774553
# 0.19278996865203762
# 0.19278996865203762
# [LibSVM]Counter({1: 5828, -1: 648})
# Counter({1: 2575, -1: 615})
# 0.8999382334774553
# 0.19278996865203762
# 0.19278996865203762
# [LibSVM]Counter({1: 5828, -1: 648})
# Counter({1: 2575, -1: 615})
# 0.8999382334774553
# 0.19278996865203762
# 0.19278996865203762
# [LibSVM]Counter({1: 5505, -1: 971})
# Counter({1: 2388, -1: 802})
# 0.8500617665225447
# 0.25141065830721004
# 0.25141065830721004
# [LibSVM]Counter({1: 5505, -1: 971})
# Counter({1: 2388, -1: 802})
# 0.8500617665225447
# 0.25141065830721004
# 0.25141065830721004
# [LibSVM]Counter({1: 5505, -1: 971})
# Counter({1: 2388, -1: 802})
# 0.8500617665225447
# 0.25141065830721004
# 0.25141065830721004
# [LibSVM]Counter({1: 5181, -1: 1295})
# Counter({1: 2193, -1: 997})
# 0.8000308832612724
# 0.31253918495297806
# 0.31253918495297806
# [LibSVM]Counter({1: 5181, -1: 1295})
# Counter({1: 2193, -1: 997})
# 0.8000308832612724
# 0.31253918495297806
# 0.31253918495297806
# [LibSVM]Counter({1: 5181, -1: 1295})
# Counter({1: 2193, -1: 997})
# 0.8000308832612724
# 0.31253918495297806
# 0.31253918495297806
# [LibSVM]Counter({1: 4533, -1: 1943})
# Counter({1: 1816, -1: 1374})
# 0.6999691167387276
# 0.4307210031347962
# [LibSVM]Counter({1: 4533, -1: 1943})
# Counter({1: 1816, -1: 1374})
# 0.6999691167387276
# 0.4307210031347962
# [LibSVM]Counter({1: 4533, -1: 1943})
# Counter({1: 1816, -1: 1374})
# 0.6999691167387276
# 0.4307210031347962
# [LibSVM]Counter({1: 3886, -1: 2590})
# Counter({-1: 1695, 1: 1495})
# 0.6000617665225447
# 0.5313479623824452
# [LibSVM]Counter({1: 3886, -1: 2590})
# Counter({-1: 1695, 1: 1495})
# 0.6000617665225447
# 0.5313479623824452
# [LibSVM]Counter({1: 3886, -1: 2590})
# Counter({-1: 1695, 1: 1495})
# 0.6000617665225447
# 0.5313479623824452
# [LibSVM]Counter({-1: 3238, 1: 3238})
# Counter({-1: 1973, 1: 1217})
# 0.5
# 0.6184952978056426
# [LibSVM]Counter({-1: 3238, 1: 3238})
# Counter({-1: 1973, 1: 1217})
# 0.5
# 0.6184952978056426
# [LibSVM]Counter({-1: 3238, 1: 3238})
# Counter({-1: 1973, 1: 1217})
# 0.5
# 0.6184952978056426
# [LibSVM]Counter({1: 6412, -1: 64})
# Counter({1: 3071, -1: 119})
# 0.990117356392835
# 0.037304075235109715
# 0.037304075235109715
# [LibSVM]Counter({1: 6412, -1: 64})
# Counter({1: 3071, -1: 119})
# 0.990117356392835
# 0.037304075235109715
# 0.037304075235109715
# [LibSVM]Counter({1: 6412, -1: 64})
# Counter({1: 3071, -1: 119})
# 0.990117356392835
# 0.037304075235109715
# 0.037304075235109715
# [LibSVM]Counter({1: 5828, -1: 648})
# Counter({1: 2575, -1: 615})
# 0.8999382334774553
# 0.19278996865203762
# 0.19278996865203762
# [LibSVM]Counter({1: 5828, -1: 648})
# Counter({1: 2575, -1: 615})
# 0.8999382334774553
# 0.19278996865203762
# 0.19278996865203762
# [LibSVM]Counter({1: 5828, -1: 648})
# Counter({1: 2575, -1: 615})
# 0.8999382334774553
# 0.19278996865203762
# 0.19278996865203762
# [LibSVM]Counter({1: 5504, -1: 972})
# Counter({1: 2388, -1: 802})
# 0.8499073502161828
# 0.25141065830721004
# 0.25141065830721004
# [LibSVM]Counter({1: 5504, -1: 972})
# Counter({1: 2388, -1: 802})
# 0.8499073502161828
# 0.25141065830721004
# 0.25141065830721004
# [LibSVM]Counter({1: 5504, -1: 972})
# Counter({1: 2388, -1: 802})
# 0.8499073502161828
# 0.25141065830721004
# 0.25141065830721004
# [LibSVM]Counter({1: 5181, -1: 1295})
# Counter({1: 2193, -1: 997})
# 0.8000308832612724
# 0.31253918495297806
# 0.31253918495297806
# [LibSVM]Counter({1: 5181, -1: 1295})
# Counter({1: 2193, -1: 997})
# 0.8000308832612724
# 0.31253918495297806
# 0.31253918495297806
# [LibSVM]Counter({1: 5181, -1: 1295})
# Counter({1: 2193, -1: 997})
# 0.8000308832612724
# 0.31253918495297806
# 0.31253918495297806
# [LibSVM]Counter({1: 4533, -1: 1943})
# Counter({1: 1816, -1: 1374})
# 0.6999691167387276
# 0.4307210031347962
# [LibSVM]Counter({1: 4533, -1: 1943})
# Counter({1: 1816, -1: 1374})
# 0.6999691167387276
# 0.4307210031347962
# [LibSVM]Counter({1: 4533, -1: 1943})
# Counter({1: 1816, -1: 1374})
# 0.6999691167387276
# 0.4307210031347962
# [LibSVM]Counter({1: 3886, -1: 2590})
# Counter({-1: 1695, 1: 1495})
# 0.6000617665225447
# 0.5313479623824452
# [LibSVM]Counter({1: 3886, -1: 2590})
# Counter({-1: 1695, 1: 1495})
# 0.6000617665225447
# 0.5313479623824452
# [LibSVM]Counter({1: 3886, -1: 2590})
# Counter({-1: 1695, 1: 1495})
# 0.6000617665225447
# 0.5313479623824452
# [LibSVM]Counter({-1: 3238, 1: 3238})
# Counter({-1: 1973, 1: 1217})
# 0.5
# 0.6184952978056426
# [LibSVM]Counter({-1: 3238, 1: 3238})
# Counter({-1: 1973, 1: 1217})
# 0.5
# 0.6184952978056426
# [LibSVM]Counter({-1: 3238, 1: 3238})
# Counter({-1: 1973, 1: 1217})
# 0.5
# 0.6184952978056426
# [LibSVM]Counter({-1: 4041, 1: 2435})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 3702, 1: 2774})
# Counter({-1: 3189, 1: 1})
# 0.42835083384805434
# 0.9996865203761756
# [LibSVM]Counter({-1: 6468, 1: 8})
# Counter({-1: 3190})
# [LibSVM]Counter({1: 5798, -1: 678})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 4779, 1: 1697})
# Counter({-1: 3190})
# [LibSVM]Counter({1: 5068, -1: 1408})
# Counter({-1: 3189, 1: 1})
# 0.7825818406423718
# 0.9996865203761756
# [LibSVM]Counter({1: 5552, -1: 924})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 4070, 1: 2406})
# Counter({-1: 3190})
# [LibSVM]Counter({1: 4495, -1: 1981})
# Counter({-1: 3190})
# [LibSVM]Counter({1: 5172, -1: 1304})
# Counter({-1: 3190})
# [LibSVM]Counter({1: 3256, -1: 3220})
# Counter({-1: 3190})
# [LibSVM]Counter({1: 3645, -1: 2831})
# Counter({-1: 3189, 1: 1})
# 0.5628474366893144
# 0.9996865203761756
# [LibSVM]Counter({1: 4633, -1: 1843})
# Counter({-1: 3190})
# [LibSVM]Counter({1: 4746, -1: 1730})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 4115, 1: 2361})
# Counter({-1: 3190})
# [LibSVM]Counter({1: 3880, -1: 2596})
# Counter({-1: 3190})
# [LibSVM]Counter({1: 6156, -1: 320})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 5609, 1: 867})
# Counter({-1: 3190})
# [LibSVM]Counter({1: 3362, -1: 3114})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 5190, 1: 1286})
# Counter({-1: 3190})
# [LibSVM]Counter({1: 5879, -1: 597})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({1: 6412, -1: 64})
# Counter({1: 3071, -1: 119})
# 0.990117356392835
# 0.037304075235109715
# 0.037304075235109715
# [LibSVM]Counter({1: 6412, -1: 64})
# Counter({1: 3071, -1: 119})
# 0.990117356392835
# 0.037304075235109715
# 0.037304075235109715
# [LibSVM]Counter({1: 6412, -1: 64})
# Counter({1: 3071, -1: 119})
# 0.990117356392835
# 0.037304075235109715
# 0.037304075235109715
# [LibSVM]Counter({1: 5828, -1: 648})
# Counter({1: 2575, -1: 615})
# 0.8999382334774553
# 0.19278996865203762
# 0.19278996865203762
# [LibSVM]Counter({1: 5828, -1: 648})
# Counter({1: 2575, -1: 615})
# 0.8999382334774553
# 0.19278996865203762
# 0.19278996865203762
# [LibSVM]Counter({1: 5828, -1: 648})
# Counter({1: 2575, -1: 615})
# 0.8999382334774553
# 0.19278996865203762
# 0.19278996865203762
# [LibSVM]Counter({1: 5505, -1: 971})
# Counter({1: 2388, -1: 802})
# 0.8500617665225447
# 0.25141065830721004
# 0.25141065830721004
# [LibSVM]Counter({1: 5505, -1: 971})
# Counter({1: 2388, -1: 802})
# 0.8500617665225447
# 0.25141065830721004
# 0.25141065830721004
# [LibSVM]Counter({1: 5505, -1: 971})
# Counter({1: 2388, -1: 802})
# 0.8500617665225447
# 0.25141065830721004
# 0.25141065830721004
# [LibSVM]Counter({1: 5181, -1: 1295})
# Counter({1: 2193, -1: 997})
# 0.8000308832612724
# 0.31253918495297806
# 0.31253918495297806
# [LibSVM]Counter({1: 5181, -1: 1295})
# Counter({1: 2193, -1: 997})
# 0.8000308832612724
# 0.31253918495297806
# 0.31253918495297806
# [LibSVM]Counter({1: 5181, -1: 1295})
# Counter({1: 2193, -1: 997})
# 0.8000308832612724
# 0.31253918495297806
# 0.31253918495297806
# [LibSVM]Counter({1: 4533, -1: 1943})
# Counter({1: 1816, -1: 1374})
# 0.6999691167387276
# 0.4307210031347962
# [LibSVM]Counter({1: 4533, -1: 1943})
# Counter({1: 1816, -1: 1374})
# 0.6999691167387276
# 0.4307210031347962
# [LibSVM]Counter({1: 4533, -1: 1943})
# Counter({1: 1816, -1: 1374})
# 0.6999691167387276
# 0.4307210031347962
# [LibSVM]Counter({1: 3886, -1: 2590})
# Counter({-1: 1695, 1: 1495})
# 0.6000617665225447
# 0.5313479623824452
# [LibSVM]Counter({1: 3886, -1: 2590})
# Counter({-1: 1695, 1: 1495})
# 0.6000617665225447
# 0.5313479623824452
# [LibSVM]Counter({1: 3886, -1: 2590})
# Counter({-1: 1695, 1: 1495})
# 0.6000617665225447
# 0.5313479623824452
# [LibSVM]Counter({-1: 3238, 1: 3238})
# Counter({-1: 1973, 1: 1217})
# 0.5
# 0.6184952978056426
# [LibSVM]Counter({-1: 3238, 1: 3238})
# Counter({-1: 1973, 1: 1217})
# 0.5
# 0.6184952978056426
# [LibSVM]Counter({-1: 3238, 1: 3238})
# Counter({-1: 1973, 1: 1217})
# 0.5
# 0.6184952978056426
# [LibSVM]Counter({1: 6412, -1: 64})
# Counter({1: 3071, -1: 119})
# 0.990117356392835
# 0.037304075235109715
# 0.037304075235109715
# [LibSVM]Counter({1: 6412, -1: 64})
# Counter({1: 3071, -1: 119})
# 0.990117356392835
# 0.037304075235109715
# 0.037304075235109715
# [LibSVM]Counter({1: 6412, -1: 64})
# Counter({1: 3071, -1: 119})
# 0.990117356392835
# 0.037304075235109715
# 0.037304075235109715
# [LibSVM]Counter({1: 5829, -1: 647})
# Counter({1: 2575, -1: 615})
# 0.9000926497838172
# 0.19278996865203762
# 0.19278996865203762
# [LibSVM]Counter({1: 5829, -1: 647})
# Counter({1: 2575, -1: 615})
# 0.9000926497838172
# 0.19278996865203762
# 0.19278996865203762
# [LibSVM]Counter({1: 5829, -1: 647})
# Counter({1: 2575, -1: 615})
# 0.9000926497838172
# 0.19278996865203762
# 0.19278996865203762
# [LibSVM]Counter({1: 5504, -1: 972})
# Counter({1: 2388, -1: 802})
# 0.8499073502161828
# 0.25141065830721004
# 0.25141065830721004
# [LibSVM]Counter({1: 5504, -1: 972})
# Counter({1: 2388, -1: 802})
# 0.8499073502161828
# 0.25141065830721004
# 0.25141065830721004
# [LibSVM]Counter({1: 5504, -1: 972})
# Counter({1: 2388, -1: 802})
# 0.8499073502161828
# 0.25141065830721004
# 0.25141065830721004
# [LibSVM]Counter({1: 5180, -1: 1296})
# Counter({1: 2193, -1: 997})
# 0.7998764669549104
# 0.31253918495297806
# [LibSVM]Counter({1: 5180, -1: 1296})
# Counter({1: 2193, -1: 997})
# 0.7998764669549104
# 0.31253918495297806
# [LibSVM]Counter({1: 5180, -1: 1296})
# Counter({1: 2193, -1: 997})
# 0.7998764669549104
# 0.31253918495297806
# [LibSVM]Counter({1: 4534, -1: 1942})
# Counter({1: 1816, -1: 1374})
# 0.7001235330450896
# 0.4307210031347962
# [LibSVM]Counter({1: 4534, -1: 1942})
# Counter({1: 1816, -1: 1374})
# 0.7001235330450896
# 0.4307210031347962
# [LibSVM]Counter({1: 4534, -1: 1942})
# Counter({1: 1816, -1: 1374})
# 0.7001235330450896
# 0.4307210031347962
# [LibSVM]Counter({1: 3886, -1: 2590})
# Counter({-1: 1695, 1: 1495})
# 0.6000617665225447
# 0.5313479623824452
# [LibSVM]Counter({1: 3886, -1: 2590})
# Counter({-1: 1695, 1: 1495})
# 0.6000617665225447
# 0.5313479623824452
# [LibSVM]Counter({1: 3886, -1: 2590})
# Counter({-1: 1695, 1: 1495})
# 0.6000617665225447
# 0.5313479623824452
# [LibSVM]Counter({-1: 3238, 1: 3238})
# Counter({-1: 1973, 1: 1217})
# 0.5
# 0.6184952978056426
# [LibSVM]Counter({-1: 3238, 1: 3238})
# Counter({-1: 1973, 1: 1217})
# 0.5
# 0.6184952978056426
# [LibSVM]Counter({-1: 3238, 1: 3238})
# Counter({-1: 1973, 1: 1217})
# 0.5
# 0.6184952978056426
# [LibSVM]Counter({-1: 4043, 1: 2433})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 3700, 1: 2776})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6468, 1: 8})
# Counter({-1: 3190})
# [LibSVM]Counter({1: 5825, -1: 651})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 4781, 1: 1695})
# Counter({-1: 3190})
# [LibSVM]Counter({1: 5069, -1: 1407})
# Counter({-1: 3190})
# [LibSVM]Counter({1: 5606, -1: 870})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 4062, 1: 2414})
# Counter({-1: 3190})
# [LibSVM]Counter({1: 4495, -1: 1981})
# Counter({-1: 3190})
# [LibSVM]Counter({1: 5197, -1: 1279})
# Counter({-1: 3190})
# [LibSVM]Counter({1: 3262, -1: 3214})
# Counter({-1: 3190})
# [LibSVM]Counter({1: 3652, -1: 2824})
# Counter({-1: 3190})
# [LibSVM]Counter({1: 4669, -1: 1807})
# Counter({-1: 3190})
# [LibSVM]Counter({1: 4761, -1: 1715})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 4112, 1: 2364})
# Counter({-1: 3190})
# [LibSVM]Counter({1: 3909, -1: 2567})
# Counter({-1: 3190})
# [LibSVM]Counter({1: 6190, -1: 286})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 5611, 1: 865})
# Counter({-1: 3190})
# [LibSVM]Counter({1: 3384, -1: 3092})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 5193, 1: 1283})
# Counter({-1: 3190})
# [LibSVM]Counter({1: 5882, -1: 594})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({1: 6412, -1: 64})
# Counter({1: 3071, -1: 119})
# 0.990117356392835
# 0.037304075235109715
# 0.037304075235109715
# [LibSVM]Counter({1: 6412, -1: 64})
# Counter({1: 3071, -1: 119})
# 0.990117356392835
# 0.037304075235109715
# 0.037304075235109715
# [LibSVM]Counter({1: 6412, -1: 64})
# Counter({1: 3071, -1: 119})
# 0.990117356392835
# 0.037304075235109715
# 0.037304075235109715
# [LibSVM]Counter({1: 5828, -1: 648})
# Counter({1: 2575, -1: 615})
# 0.8999382334774553
# 0.19278996865203762
# 0.19278996865203762
# [LibSVM]Counter({1: 5828, -1: 648})
# Counter({1: 2575, -1: 615})
# 0.8999382334774553
# 0.19278996865203762
# 0.19278996865203762
# [LibSVM]Counter({1: 5828, -1: 648})
# Counter({1: 2575, -1: 615})
# 0.8999382334774553
# 0.19278996865203762
# 0.19278996865203762
# [LibSVM]Counter({1: 5505, -1: 971})
# Counter({1: 2388, -1: 802})
# 0.8500617665225447
# 0.25141065830721004
# 0.25141065830721004
# [LibSVM]Counter({1: 5505, -1: 971})
# Counter({1: 2388, -1: 802})
# 0.8500617665225447
# 0.25141065830721004
# 0.25141065830721004
# [LibSVM]Counter({1: 5505, -1: 971})
# Counter({1: 2388, -1: 802})
# 0.8500617665225447
# 0.25141065830721004
# 0.25141065830721004
# [LibSVM]Counter({1: 5181, -1: 1295})
# Counter({1: 2193, -1: 997})
# 0.8000308832612724
# 0.31253918495297806
# 0.31253918495297806
# [LibSVM]Counter({1: 5181, -1: 1295})
# Counter({1: 2193, -1: 997})
# 0.8000308832612724
# 0.31253918495297806
# 0.31253918495297806
# [LibSVM]Counter({1: 5181, -1: 1295})
# Counter({1: 2193, -1: 997})
# 0.8000308832612724
# 0.31253918495297806
# 0.31253918495297806
# [LibSVM]Counter({1: 4533, -1: 1943})
# Counter({1: 1816, -1: 1374})
# 0.6999691167387276
# 0.4307210031347962
# [LibSVM]Counter({1: 4533, -1: 1943})
# Counter({1: 1816, -1: 1374})
# 0.6999691167387276
# 0.4307210031347962
# [LibSVM]Counter({1: 4533, -1: 1943})
# Counter({1: 1816, -1: 1374})
# 0.6999691167387276
# 0.4307210031347962
# [LibSVM]Counter({1: 3886, -1: 2590})
# Counter({-1: 1695, 1: 1495})
# 0.6000617665225447
# 0.5313479623824452
# [LibSVM]Counter({1: 3886, -1: 2590})
# Counter({-1: 1695, 1: 1495})
# 0.6000617665225447
# 0.5313479623824452
# [LibSVM]Counter({1: 3886, -1: 2590})
# Counter({-1: 1695, 1: 1495})
# 0.6000617665225447
# 0.5313479623824452
# [LibSVM]Counter({-1: 3238, 1: 3238})
# Counter({-1: 1973, 1: 1217})
# 0.5
# 0.6184952978056426
# [LibSVM]Counter({-1: 3238, 1: 3238})
# Counter({-1: 1973, 1: 1217})
# 0.5
# 0.6184952978056426
# [LibSVM]Counter({-1: 3238, 1: 3238})
# Counter({-1: 1973, 1: 1217})
# 0.5
# 0.6184952978056426
# [LibSVM]Counter({1: 6412, -1: 64})
# Counter({1: 3071, -1: 119})
# 0.990117356392835
# 0.037304075235109715
# 0.037304075235109715
# [LibSVM]Counter({1: 6412, -1: 64})
# Counter({1: 3071, -1: 119})
# 0.990117356392835
# 0.037304075235109715
# 0.037304075235109715
# [LibSVM]Counter({1: 6412, -1: 64})
# Counter({1: 3071, -1: 119})
# 0.990117356392835
# 0.037304075235109715
# 0.037304075235109715
# [LibSVM]Counter({1: 5828, -1: 648})
# Counter({1: 2575, -1: 615})
# 0.8999382334774553
# 0.19278996865203762
# 0.19278996865203762
# [LibSVM]Counter({1: 5828, -1: 648})
# Counter({1: 2575, -1: 615})
# 0.8999382334774553
# 0.19278996865203762
# 0.19278996865203762
# [LibSVM]Counter({1: 5828, -1: 648})
# Counter({1: 2575, -1: 615})
# 0.8999382334774553
# 0.19278996865203762
# 0.19278996865203762
# [LibSVM]Counter({1: 5504, -1: 972})
# Counter({1: 2388, -1: 802})
# 0.8499073502161828
# 0.25141065830721004
# 0.25141065830721004
# [LibSVM]Counter({1: 5504, -1: 972})
# Counter({1: 2388, -1: 802})
# 0.8499073502161828
# 0.25141065830721004
# 0.25141065830721004
# [LibSVM]Counter({1: 5504, -1: 972})
# Counter({1: 2388, -1: 802})
# 0.8499073502161828
# 0.25141065830721004
# 0.25141065830721004
# [LibSVM]Counter({1: 5180, -1: 1296})
# Counter({1: 2193, -1: 997})
# 0.7998764669549104
# 0.31253918495297806
# [LibSVM]Counter({1: 5180, -1: 1296})
# Counter({1: 2193, -1: 997})
# 0.7998764669549104
# 0.31253918495297806
# [LibSVM]Counter({1: 5180, -1: 1296})
# Counter({1: 2193, -1: 997})
# 0.7998764669549104
# 0.31253918495297806
# [LibSVM]Counter({1: 4533, -1: 1943})
# Counter({1: 1816, -1: 1374})
# 0.6999691167387276
# 0.4307210031347962
# [LibSVM]Counter({1: 4533, -1: 1943})
# Counter({1: 1816, -1: 1374})
# 0.6999691167387276
# 0.4307210031347962
# [LibSVM]Counter({1: 4533, -1: 1943})
# Counter({1: 1816, -1: 1374})
# 0.6999691167387276
# 0.4307210031347962
# [LibSVM]Counter({1: 3885, -1: 2591})
# Counter({-1: 1695, 1: 1495})
# 0.5999073502161828
# 0.5313479623824452
# [LibSVM]Counter({1: 3885, -1: 2591})
# Counter({-1: 1695, 1: 1495})
# 0.5999073502161828
# 0.5313479623824452
# [LibSVM]Counter({1: 3885, -1: 2591})
# Counter({-1: 1695, 1: 1495})
# 0.5999073502161828
# 0.5313479623824452
# [LibSVM]Counter({-1: 3238, 1: 3238})
# Counter({-1: 1973, 1: 1217})
# 0.5
# 0.6184952978056426
# [LibSVM]Counter({-1: 3238, 1: 3238})
# Counter({-1: 1973, 1: 1217})
# 0.5
# 0.6184952978056426
# [LibSVM]Counter({-1: 3238, 1: 3238})
# Counter({-1: 1973, 1: 1217})
# 0.5
# 0.6184952978056426
# [LibSVM]Counter({1: 3775, -1: 2701})
# Counter({-1: 3188, 1: 2})
# 0.5829215565163681
# 0.9993730407523511
# [LibSVM]Counter({-1: 3627, 1: 2849})
# Counter({-1: 3185, 1: 5})
# 0.43993205682520076
# 0.9984326018808778
# [LibSVM]Counter({-1: 6467, 1: 9})
# Counter({-1: 3190})
# [LibSVM]Counter({1: 3653, -1: 2823})
# Counter({-1: 3190})
# [LibSVM]Counter({1: 3355, -1: 3121})
# Counter({-1: 3188, 1: 2})
# 0.5180667078443484
# 0.9993730407523511
# [LibSVM]Counter({1: 5240, -1: 1236})
# Counter({-1: 3188, 1: 2})
# 0.8091414453366276
# 0.9993730407523511
# [LibSVM]Counter({-1: 3666, 1: 2810})
# Counter({-1: 3190})
# [LibSVM]Counter({1: 4827, -1: 1649})
# Counter({-1: 3188, 1: 2})
# 0.7453675108091414
# 0.9993730407523511
# [LibSVM]Counter({1: 4466, -1: 2010})
# Counter({-1: 3189, 1: 1})
# 0.6896232242124768
# 0.9996865203761756
# [LibSVM]Counter({-1: 3393, 1: 3083})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 4347, 1: 2129})
# Counter({-1: 3189, 1: 1})
# 0.32875231624459544
# 0.9996865203761756
# [LibSVM]Counter({1: 4245, -1: 2231})
# Counter({-1: 3188, 1: 2})
# 0.6554972205064855
# 0.9993730407523511
# [LibSVM]Counter({1: 3985, -1: 2491})
# Counter({-1: 3190})
# [LibSVM]Counter({1: 4227, -1: 2249})
# Counter({-1: 3190})
# [LibSVM]Counter({1: 3282, -1: 3194})
# Counter({-1: 3188, 1: 2})
# 0.5067943174799259
# 0.9993730407523511
# [LibSVM]Counter({-1: 3381, 1: 3095})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 3415, 1: 3061})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 4148, 1: 2328})
# Counter({-1: 3189, 1: 1})
# 0.35948116121062385
# 0.9996865203761756
# [LibSVM]Counter({-1: 3307, 1: 3169})
# Counter({-1: 3190})
# [LibSVM]Counter({1: 3261, -1: 3215})
# Counter({-1: 3189, 1: 1})
# 0.5035515750463249
# 0.9996865203761756
# [LibSVM]Counter({-1: 4820, 1: 1656})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({-1: 6476})
# Counter({-1: 3190})
# [LibSVM]Counter({1: 6412, -1: 64})
# Counter({1: 3071, -1: 119})
# 0.990117356392835
# 0.037304075235109715
# 0.037304075235109715
# [LibSVM]Counter({1: 6412, -1: 64})
# Counter({1: 3071, -1: 119})
# 0.990117356392835
# 0.037304075235109715
# 0.037304075235109715
# [LibSVM]Counter({1: 6412, -1: 64})
# Counter({1: 3071, -1: 119})
# 0.990117356392835
# 0.037304075235109715
# 0.037304075235109715
# [LibSVM]Counter({1: 5828, -1: 648})
# Counter({1: 2575, -1: 615})
# 0.8999382334774553
# 0.19278996865203762
# 0.19278996865203762
# [LibSVM]Counter({1: 5828, -1: 648})
# Counter({1: 2575, -1: 615})
# 0.8999382334774553
# 0.19278996865203762
# 0.19278996865203762
# [LibSVM]Counter({1: 5828, -1: 648})
# Counter({1: 2575, -1: 615})
# 0.8999382334774553
# 0.19278996865203762
# 0.19278996865203762
# [LibSVM]Counter({1: 5505, -1: 971})
# Counter({1: 2388, -1: 802})
# 0.8500617665225447
# 0.25141065830721004
# 0.25141065830721004
# [LibSVM]Counter({1: 5505, -1: 971})
# Counter({1: 2388, -1: 802})
# 0.8500617665225447
# 0.25141065830721004
# 0.25141065830721004
# [LibSVM]Counter({1: 5505, -1: 971})
# Counter({1: 2388, -1: 802})
# 0.8500617665225447
# 0.25141065830721004
# 0.25141065830721004
# [LibSVM]Counter({1: 5181, -1: 1295})
# Counter({1: 2193, -1: 997})
# 0.8000308832612724
# 0.31253918495297806
# 0.31253918495297806
# [LibSVM]Counter({1: 5181, -1: 1295})
# Counter({1: 2193, -1: 997})
# 0.8000308832612724
# 0.31253918495297806
# 0.31253918495297806
# [LibSVM]Counter({1: 5181, -1: 1295})
# Counter({1: 2193, -1: 997})
# 0.8000308832612724
# 0.31253918495297806
# 0.31253918495297806
# [LibSVM]Counter({1: 4533, -1: 1943})
# Counter({1: 1816, -1: 1374})
# 0.6999691167387276
# 0.4307210031347962
# [LibSVM]Counter({1: 4533, -1: 1943})
# Counter({1: 1816, -1: 1374})
# 0.6999691167387276
# 0.4307210031347962
# [LibSVM]Counter({1: 4533, -1: 1943})
# Counter({1: 1816, -1: 1374})
# 0.6999691167387276
# 0.4307210031347962
# [LibSVM]Counter({1: 3886, -1: 2590})
# Counter({-1: 1695, 1: 1495})
# 0.6000617665225447
# 0.5313479623824452
# [LibSVM]Counter({1: 3886, -1: 2590})
# Counter({-1: 1695, 1: 1495})
# 0.6000617665225447
# 0.5313479623824452
# [LibSVM]Counter({1: 3886, -1: 2590})
# Counter({-1: 1695, 1: 1495})
# 0.6000617665225447
# 0.5313479623824452
# [LibSVM]Counter({-1: 3238, 1: 3238})
# Counter({-1: 1973, 1: 1217})
# 0.5
# 0.6184952978056426
# [LibSVM]Counter({-1: 3238, 1: 3238})
# Counter({-1: 1973, 1: 1217})
# 0.5
# 0.6184952978056426
# [LibSVM]Counter({-1: 3238, 1: 3238})
# Counter({-1: 1973, 1: 1217})
# 0.5
# 0.6184952978056426
# [LibSVM]Counter({1: 6412, -1: 64})
# Counter({1: 3071, -1: 119})
# 0.990117356392835
# 0.037304075235109715
# 0.037304075235109715
# [LibSVM]Counter({1: 6412, -1: 64})
# Counter({1: 3071, -1: 119})
# 0.990117356392835
# 0.037304075235109715
# 0.037304075235109715
# [LibSVM]Counter({1: 6412, -1: 64})
# Counter({1: 3071, -1: 119})
# 0.990117356392835
# 0.037304075235109715
# 0.037304075235109715
# [LibSVM]Counter({1: 5829, -1: 647})
# Counter({1: 2575, -1: 615})
# 0.9000926497838172
# 0.19278996865203762
# 0.19278996865203762
# [LibSVM]Counter({1: 5829, -1: 647})
# Counter({1: 2575, -1: 615})
# 0.9000926497838172
# 0.19278996865203762
# 0.19278996865203762
# [LibSVM]Counter({1: 5829, -1: 647})
# Counter({1: 2575, -1: 615})
# 0.9000926497838172
# 0.19278996865203762
# 0.19278996865203762
# [LibSVM]Counter({1: 5505, -1: 971})
# Counter({1: 2388, -1: 802})
# 0.8500617665225447
# 0.25141065830721004
# 0.25141065830721004
# [LibSVM]Counter({1: 5505, -1: 971})
# Counter({1: 2388, -1: 802})
# 0.8500617665225447
# 0.25141065830721004
# 0.25141065830721004
# [LibSVM]Counter({1: 5505, -1: 971})
# Counter({1: 2388, -1: 802})
# 0.8500617665225447
# 0.25141065830721004
# 0.25141065830721004
# [LibSVM]Counter({1: 5181, -1: 1295})
# Counter({1: 2193, -1: 997})
# 0.8000308832612724
# 0.31253918495297806
# 0.31253918495297806
# [LibSVM]Counter({1: 5181, -1: 1295})
# Counter({1: 2193, -1: 997})
# 0.8000308832612724
# 0.31253918495297806
# 0.31253918495297806
# [LibSVM]Counter({1: 5181, -1: 1295})
# Counter({1: 2193, -1: 997})
# 0.8000308832612724
# 0.31253918495297806
# 0.31253918495297806
# [LibSVM]Counter({1: 4534, -1: 1942})
# Counter({1: 1816, -1: 1374})
# 0.7001235330450896
# 0.4307210031347962
# [LibSVM]Counter({1: 4534, -1: 1942})
# Counter({1: 1816, -1: 1374})
# 0.7001235330450896
# 0.4307210031347962
# [LibSVM]Counter({1: 4534, -1: 1942})
# Counter({1: 1816, -1: 1374})
# 0.7001235330450896
# 0.4307210031347962
# [LibSVM]Counter({1: 3886, -1: 2590})
# Counter({-1: 1695, 1: 1495})
# 0.6000617665225447
# 0.5313479623824452
# [LibSVM]Counter({1: 3886, -1: 2590})
# Counter({-1: 1695, 1: 1495})
# 0.6000617665225447
# 0.5313479623824452
# [LibSVM]Counter({1: 3886, -1: 2590})
# Counter({-1: 1695, 1: 1495})
# 0.6000617665225447
# 0.5313479623824452
# [LibSVM]Counter({-1: 3238, 1: 3238})
# Counter({-1: 1973, 1: 1217})
# 0.5
# 0.6184952978056426
# [LibSVM]Counter({-1: 3238, 1: 3238})
# Counter({-1: 1973, 1: 1217})
# 0.5
# 0.6184952978056426
# [LibSVM]Counter({-1: 3238, 1: 3238})
# Counter({-1: 1973, 1: 1217})
# 0.5
# 0.6184952978056426
# [LibSVM]Counter({-1: 4033, 1: 2443})
# Counter({-1: 3190})
# [LibSVM]

# %%
check_best_result(clf, best_params_list, X_train, X_test, X_out)

# %%
leafs = [ 1,3,5,9,12,17,20,25,35,50]
neighbours = [ 1,3,5,9,12,17,20,25,35,50]
contaminations = [0.001, 0.01, 0.15,0.2,0.5]
p = [1,2]
algs = ['auto', 'ball_tree', 'kd_tree', 'brute']

grid = {'leaf_size': leafs, 'n_neighbors' : neighbours, 'contamination' : contaminations, 'algorithm' : algs, 'p': p}
clf = LocalOutlierFactor(novelty=True, n_jobs=-1)

best_score_list, best_params_list = fit_and_display(grid, clf, X_out, X_train)

# %%
check_best_result(clf, best_params_list, X_train, X_test, X_out)

# %%
estims = [ 20,50,80,120,180,400,600,900,1300,2000,3000,5000,8000]
neighbours = [ 1,3,5,9,12,17,20,25,35,50]
contaminations = [0.001, 0.01, 0.15,0.2,0.5]
boots = [True, False]

grid = { 'n_estimators' : estims, 'contamination' : contaminations, 'bootstrap' : boots}
clf = IsolationForest(behaviour="new", n_jobs=-1, verbose=10)

best_score_list, best_params_list = fit_and_display(grid, clf, X_out, X_train)

# %%
check_best_result(clf, best_params_list, X_train, X_test, X_out)
